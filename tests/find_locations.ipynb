# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the data
data = pd.read_excel('/Users/mperuzzo/Documents/repos/bottlenecks/data/raw/hart_maize/Supplemental material 1.xlsx')
data.columns
# Out:
# Index(['Site', 'Region', 'State/Privince', 'Latitude', 'Longitude', 'certain',
#        'Evidence', 'Material Dated', 'Lab No.', '14C age', '14C age 1σ',
#        'Sources'],
#       dtype='object')

# %%
for site in data.Site.unique():
    print(data.loc[data.Site == site, ['Site','Region','State/Privince']].iloc[0])
    print('\n')
# Out:
# Site              Xihuatoxtia
# Region                 Mexico
# State/Privince       Guerrero
# Name: 0, dtype: object
#
#
# Site              San Andres
# Region                Mexico
# State/Privince       Tabasco
# Name: 1, dtype: object
#
#
# Site              Pijijiapan
# Region                Mexico
# State/Privince       Chiapas
# Name: 4, dtype: object
#
#
# Site              Guilá Naquitz
# Region                   Mexico
# State/Privince           Oaxaca
# Name: 6, dtype: object
#
#
# Site              Tehuacan Caves
# Region                    Mexico
# State/Privince            Puebla
# Name: 8, dtype: object
#
#
# Site              San Marcos
# Region                Mexico
# State/Privince        Puebla
# Name: 11, dtype: object
#
#
# Site              San Marcos Cave
# Region                     Mexico
# State/Privince             Puebla
# Name: 19, dtype: object
#
#
# Site              San Marcoas Cave
# Region                      Mexico
# State/Privince              Puebla
# Name: 22, dtype: object
#
#
# Site                     Zohapilco
# Region                      Mexico
# State/Privince    Valley de Chalco
# Name: 25, dtype: object
#
#
# Site              Coastal Plain Lake
# Region                        Mexico
# State/Privince              Veracruz
# Name: 30, dtype: object
#
#
# Site              Coxcatlán
# Region               Mexico
# State/Privince       Puebla
# Name: 32, dtype: object
#
#
# Site              Romero's Cave
# Region                   Mexico
# State/Privince       Tamaulipas
# Name: 35, dtype: object
#
#
# Site              Valenzuela's Cave
# Region                       Mexico
# State/Privince           Tamaulipas
# Name: 36, dtype: object
#
#
# Site                 Lake Cobá
# Region                  Mexico
# State/Privince    Quintana Roo
# Name: 37, dtype: object
#
#
# Site              El Riego
# Region              Mexico
# State/Privince      Puebla
# Name: 38, dtype: object
#
#
# Site              Lake Pátzcuar
# Region                   Mexico
# State/Privince        Michoacán
# Name: 40, dtype: object
#
#
# Site              San Carlos
# Region                Mexico
# State/Privince       Chiapas
# Name: 44, dtype: object
#
#
# Site              Paso de la Amada
# Region                      Mexico
# State/Privince             Chiapas
# Name: 45, dtype: object
#
#
# Site              Cuauhtémoc
# Region                Mexico
# State/Privince       Chiapas
# Name: 46, dtype: object
#
#
# Site              Aquiles Serdán
# Region                    Mexico
# State/Privince           Chiapas
# Name: 50, dtype: object
#
#
# Site                Chilo
# Region             Mexico
# State/Privince    Chiapas
# Name: 54, dtype: object
#
#
# Site              Purrón
# Region            Mexico
# State/Privince    Puebla
# Name: 56, dtype: object
#
#
# Site                 Tetel
# Region              Mexico
# State/Privince    Tlaxcala
# Name: 69, dtype: object
#
#
# Site              El Cerrito
# Region                Mexico
# State/Privince       Chiapas
# Name: 90, dtype: object
#
#
# Site              El Abra II
# Region                Mexico
# State/Privince      Guerrero
# Name: 91, dtype: object
#
#
# Site                              Mobak
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 92, dtype: object
#
#
# Site                          Las Capas
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 93, dtype: object
#
#
# Site                          Los Pozos
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 95, dtype: object
#
#
# Site                LA 18103
# Region             Southwest
# State/Privince    New Mexico
# Name: 97, dtype: object
#
#
# Site              Chaco Canyon
# Region               Southwest
# State/Privince      New Mexico
# Name: 98, dtype: object
#
#
# Site                                  Old Corn
# Region                               Southwest
# State/Privince    New Mexico, Colorado Plateau
# Name: 99, dtype: object
#
#
# Site                                  Bat Cave
# Region                               Southwest
# State/Privince    New Mexico, Colorado Plateau
# Name: 101, dtype: object
#
#
# Site                         Clearwater
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 103, dtype: object
#
#
# Site              McEuen Cave
# Region              Southwest
# State/Privince        Arizona
# Name: 107, dtype: object
#
#
# Site                LA 17337
# Region             Southwest
# State/Privince    New Mexico
# Name: 108, dtype: object
#
#
# Site                 Montoya
# Region             Southwest
# State/Privince    New Mexico
# Name: 115, dtype: object
#
#
# Site                      Three Fir Shelter
# Region                            Southwest
# State/Privince    Arizona, Colorado Plateau
# Name: 119, dtype: object
#
#
# Site                        Square Hearth
# Region                          Southwest
# State/Privince    Southwest, Tucson Basin
# Name: 121, dtype: object
#
#
# Site              Lukachukai
# Region             Southwest
# State/Privince       Arizona
# Name: 122, dtype: object
#
#
# Site              Cerro Prieto de Santa Bárbara
# Region                                Southwest
# State/Privince                        Chihuahua
# Name: 125, dtype: object
#
#
# Site               LA 10577
# Region            Southwest
# State/Privince      Arizona
# Name: 126, dtype: object
#
#
# Site              Cortaro Road
# Region               Southwest
# State/Privince         Arizona
# Name: 128, dtype: object
#
#
# Site                       Valley Farms
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 132, dtype: object
#
#
# Site              Lucachukai
# Region             Southwest
# State/Privince       Arizona
# Name: 134, dtype: object
#
#
# Site              Cerro Juanaquena
# Region                   Southwest
# State/Privince           Chihuahua
# Name: 135, dtype: object
#
#
# Site                       San Luis de Cabezon
# Region                               Southwest
# State/Privince    New Mexico, Colorado Plateau
# Name: 137, dtype: object
#
#
# Site              Outpost Estates
# Region                  Southwest
# State/Privince            Arizona
# Name: 149, dtype: object
#
#
# Site                          El Taller
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 153, dtype: object
#
#
# Site              High Rolls Cave
# Region                  Southwest
# State/Privince         New Mexico
# Name: 157, dtype: object
#
#
# Site                     La Playa
# Region                  Southwest
# State/Privince    Sonora, Sonoran
# Name: 171, dtype: object
#
#
# Site                                Jemez Cave
# Region                               Southwest
# State/Privince    New Mexico, Colorado Plateau
# Name: 174, dtype: object
#
#
# Site              Eagle's Watch
# Region                Southwest
# State/Privince             Utah
# Name: 176, dtype: object
#
#
# Site              Fresnal Shelter
# Region                  Southwest
# State/Privince         New Mexico
# Name: 188, dtype: object
#
#
# Site                            Milagro
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 201, dtype: object
#
#
# Site              Cerro Los Torres
# Region                   Southwest
# State/Privince           Chihuahua
# Name: 204, dtype: object
#
#
# Site              Stewart Brickyard
# Region                    Southwest
# State/Privince              Arizona
# Name: 227, dtype: object
#
#
# Site                        Rillito Fan
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 243, dtype: object
#
#
# Site                           Solar Well
# Region                          Southwest
# State/Privince    Southwest, Tucson Basin
# Name: 252, dtype: object
#
#
# Site                         Dairy Site
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 254, dtype: object
#
#
# Site               Fairbank
# Region            Southwest
# State/Privince      Arizona
# Name: 266, dtype: object
#
#
# Site              EE:2:437(ASM)
# Region                Southwest
# State/Privince          Arizona
# Name: 269, dtype: object
#
#
# Site              Cortalo Fan
# Region              Southwest
# State/Privince        Arizona
# Name: 271, dtype: object
#
#
# Site              EE:2:438(ASM)
# Region                Southwest
# State/Privince          Arizona
# Name: 272, dtype: object
#
#
# Site              Wetlands Site
# Region                Southwest
# State/Privince          Arizona
# Name: 277, dtype: object
#
#
# Site                      Costello-King
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 280, dtype: object
#
#
# Site              Wood Canyon
# Region              Southwest
# State/Privince     New Mexico
# Name: 299, dtype: object
#
#
# Site              Tinajas Atlas?
# Region                 Southwest
# State/Privince           Arizona
# Name: 307, dtype: object
#
#
# Site               West End
# Region            Southwest
# State/Privince      Arizona
# Name: 308, dtype: object
#
#
# Site                 LA32964
# Region             Southwest
# State/Privince    New Mexico
# Name: 328, dtype: object
#
#
# Site                         Salina Springs
# Region                            Southwest
# State/Privince    Arizona, Colorado Plateau
# Name: 342, dtype: object
#
#
# Site              Cortaro Fan
# Region              Southwest
# State/Privince        Arizona
# Name: 348, dtype: object
#
#
# Site              Fairbanks
# Region            Southwest
# State/Privince      Arizona
# Name: 350, dtype: object
#
#
# Site              Mescal Wash
# Region              Southwest
# State/Privince        Arizona
# Name: 353, dtype: object
#
#
# Site              Insulator Site
# Region                 Southwest
# State/Privince        New Mexico
# Name: 355, dtype: object
#
#
# Site                  Clark
# Region            Southwest
# State/Privince      Arizona
# Name: 356, dtype: object
#
#
# Site              Charleston
# Region             Southwest
# State/Privince       Arizona
# Name: 358, dtype: object
#
#
# Site              Boomerang Shelter
# Region                    Southwest
# State/Privince                 Utah
# Name: 366, dtype: object
#
#
# Site              AA:12:96(ASM)
# Region                Southwest
# State/Privince          Arizona
# Name: 376, dtype: object
#
#
# Site              Twin Butte
# Region             Southwest
# State/Privince       Arizona
# Name: 378, dtype: object
#
#
# Site              Donaldson
# Region            Southwest
# State/Privince      Arizona
# Name: 380, dtype: object
#
#
# Site                     JR
# Region            Southwest
# State/Privince      Arizona
# Name: 387, dtype: object
#
#
# Site                  Coati
# Region            Southwest
# State/Privince      Arizona
# Name: 399, dtype: object
#
#
# Site               LA 159879
# Region             Southwest
# State/Privince    New Mexico
# Name: 400, dtype: object
#
#
# Site               LA 70667
# Region            Southwest
# State/Privince     Colorado
# Name: 403, dtype: object
#
#
# Site              Santa Crus Bend
# Region                  Southwest
# State/Privince            Arizona
# Name: 409, dtype: object
#
#
# Site              Stone Pipe
# Region             Southwest
# State/Privince       Arizona
# Name: 426, dtype: object
#
#
# Site                LA 53488
# Region             Southwest
# State/Privince    New Mexico
# Name: 431, dtype: object
#
#
# Site              Six Toe Shelter
# Region                  Southwest
# State/Privince               Utah
# Name: 432, dtype: object
#
#
# Site                LA145985
# Region             Southwest
# State/Privince    New Mexico
# Name: 436, dtype: object
#
#
# Site              Cerro Vidal
# Region              Southwest
# State/Privince      Chihuahua
# Name: 437, dtype: object
#
#
# Site                    Duke
# Region             Southwest
# State/Privince    New Mexico
# Name: 438, dtype: object
#
#
# Site                K:10:28
# Region            Southwest
# State/Privince      Arizona
# Name: 444, dtype: object
#
#
# Site              Julian Wash
# Region              Southwest
# State/Privince        Arizona
# Name: 449, dtype: object
#
#
# Site              Santa Cruz Bend
# Region                  Southwest
# State/Privince            Arizona
# Name: 452, dtype: object
#
#
# Site                      SU
# Region             Southwest
# State/Privince    New Mexico
# Name: 454, dtype: object
#
#
# Site                Ganóchi
# Region            Southwest
# State/Privince    Chihuahua
# Name: 455, dtype: object
#
#
# Site              Forest Home
# Region              Southwest
# State/Privince     New Mexico
# Name: 456, dtype: object
#
#
# Site              Alvey Shelter
# Region                Southwest
# State/Privince             Utah
# Name: 458, dtype: object
#
#
# Site              Tumamoc Hill
# Region               Southwest
# State/Privince         Arizona
# Name: 464, dtype: object
#
#
# Site              Dog Leg Site
# Region               Southwest
# State/Privince      New Mexico
# Name: 470, dtype: object
#
#
# Site                 LA79500
# Region             Southwest
# State/Privince    New Mexico
# Name: 472, dtype: object
#
#
# Site               The Pits
# Region            Southwest
# State/Privince     Colorado
# Name: 474, dtype: object
#
#
# Site              Cottonwood Cave
# Region                  Southwest
# State/Privince           Colorado
# Name: 477, dtype: object
#
#
# Site                 K:10:9
# Region            Southwest
# State/Privince      Arizona
# Name: 478, dtype: object
#
#
# Site              Kin Kahuna
# Region             Southwest
# State/Privince       Arizona
# Name: 481, dtype: object
#
#
# Site              D:11:1410
# Region            Southwest
# State/Privince      Arizona
# Name: 485, dtype: object
#
#
# Site                LA104106
# Region             Southwest
# State/Privince    New Mexico
# Name: 491, dtype: object
#
#
# Site               Darkmold
# Region            Southwest
# State/Privince     Colorado
# Name: 504, dtype: object
#
#
# Site                  Harris
# Region             Southwest
# State/Privince    New Mexico
# Name: 505, dtype: object
#
#
# Site                D:7:236
# Region            Southwest
# State/Privince      Arizona
# Name: 508, dtype: object
#
#
# Site                LA103453
# Region             Southwest
# State/Privince    New Mexico
# Name: 511, dtype: object
#
#
# Site              Talus Village
# Region                Southwest
# State/Privince         Colorado
# Name: 515, dtype: object
#
#
# Site              Duncan Donut
# Region               Southwest
# State/Privince         Arizona
# Name: 516, dtype: object
#
#
# Site              Falls Creek, N Shelter
# Region                         Southwest
# State/Privince                  Colorado
# Name: 523, dtype: object
#
#
# Site              Mogollon Village
# Region                   Southwest
# State/Privince          New Mexico
# Name: 531, dtype: object
#
#
# Site              Larder Site
# Region              Southwest
# State/Privince         Nevada
# Name: 535, dtype: object
#
#
# Site              Holahei Scatter
# Region                  Southwest
# State/Privince            Arizona
# Name: 538, dtype: object
#
#
# Site              Sandy Rise Site
# Region                  Southwest
# State/Privince         New Mexico
# Name: 543, dtype: object
#
#
# Site              Lisbon Valley
# Region                Southwest
# State/Privince             Utah
# Name: 546, dtype: object
#
#
# Site                Schmidt
# Region            Southwest
# State/Privince     Colorado
# Name: 550, dtype: object
#
#
# Site              Cowboy Cave
# Region              Southwest
# State/Privince           Utah
# Name: 551, dtype: object
#
#
# Site                K:13:60
# Region            Southwest
# State/Privince      Arizona
# Name: 557, dtype: object
#
#
# Site              Ditch House
# Region              Southwest
# State/Privince     New Mexico
# Name: 565, dtype: object
#
#
# Site              Eagle's  Watch
# Region                 Southwest
# State/Privince              Utah
# Name: 566, dtype: object
#
#
# Site              Ko' Lanhi
# Region            Southwest
# State/Privince      Arizona
# Name: 568, dtype: object
#
#
# Site                LA115327
# Region             Southwest
# State/Privince    New Mexico
# Name: 573, dtype: object
#
#
# Site                LA115330
# Region             Southwest
# State/Privince    New Mexico
# Name: 574, dtype: object
#
#
# Site              Layer Cake Site
# Region                  Southwest
# State/Privince         New Mexico
# Name: 575, dtype: object
#
#
# Site                LA123291
# Region             Southwest
# State/Privince    New Mexico
# Name: 578, dtype: object
#
#
# Site              Tabeguache Cave
# Region                  Southwest
# State/Privince           Colorado
# Name: 580, dtype: object
#
#
# Site                          Turkey Pen
# Region                         Southwest
# State/Privince    Utah, Colorado Plateau
# Name: 584, dtype: object
#
#
# Site                LA139244
# Region             Southwest
# State/Privince    New Mexico
# Name: 594, dtype: object
#
#
# Site              Schmidt Site
# Region               Southwest
# State/Privince        Colorado
# Name: 597, dtype: object
#
#
# Site                LA122034
# Region             Southwest
# State/Privince    New Mexico
# Name: 601, dtype: object
#
#
# Site              Trail Canyon
# Region               Southwest
# State/Privince         Arizona
# Name: 608, dtype: object
#
#
# Site              Rock Canyon Shelter
# Region                      Southwest
# State/Privince                Arizona
# Name: 610, dtype: object
#
#
# Site              Eagle Watch
# Region              Southwest
# State/Privince           Utah
# Name: 613, dtype: object
#
#
# Site               42KA6043
# Region            Southwest
# State/Privince         Utah
# Name: 614, dtype: object
#
#
# Site              Cerro La Noria
# Region                 Southwest
# State/Privince         Chihuahua
# Name: 617, dtype: object
#
#
# Site              Eagle Rock Shelter
# Region                     Southwest
# State/Privince              Colorado
# Name: 619, dtype: object
#
#
# Site                             Tularosa Cave
# Region                               Southwest
# State/Privince    New Mexico, Colorado Plateau
# Name: 626, dtype: object
#
#
# Site              Black Dog Cave
# Region                 Southwest
# State/Privince            Nevada
# Name: 627, dtype: object
#
#
# Site               42WS5167
# Region            Southwest
# State/Privince         Utah
# Name: 634, dtype: object
#
#
# Site              Colluvial Rock Shelter
# Region                         Southwest
# State/Privince                      Utah
# Name: 641, dtype: object
#
#
# Site              Mountain Boomer
# Region                  Southwest
# State/Privince               Utah
# Name: 644, dtype: object
#
#
# Site              Obsidian Cache Pithouse
# Region                          Southwest
# State/Privince                       Utah
# Name: 650, dtype: object
#
#
# Site                 Sniper
# Region            Southwest
# State/Privince      Arizona
# Name: 651, dtype: object
#
#
# Site              Myron Taylor Site
# Region                    Southwest
# State/Privince             Colorado
# Name: 664, dtype: object
#
#
# Site              Sin Sombra
# Region             Southwest
# State/Privince       Arizona
# Name: 665, dtype: object
#
#
# Site              Three Dog Site
# Region                 Southwest
# State/Privince           Arizona
# Name: 666, dtype: object
#
#
# Site                     Valencia Bieja
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 667, dtype: object
#
#
# Site                 5LP188
# Region            Southwest
# State/Privince     Colorado
# Name: 668, dtype: object
#
#
# Site               Beargrass
# Region             Southwest
# State/Privince    New Mexico
# Name: 669, dtype: object
#
#
# Site              Chama Alcove
# Region               Southwest
# State/Privince      New Mexico
# Name: 670, dtype: object
#
#
# Site              Desha Cave 1
# Region               Southwest
# State/Privince            Utah
# Name: 672, dtype: object
#
#
# Site                 LA72717
# Region             Southwest
# State/Privince    New Mexico
# Name: 674, dtype: object
#
#
# Site                  BC 236
# Region             Southwest
# State/Privince    New Mexico
# Name: 678, dtype: object
#
#
# Site              Mountainview
# Region               Southwest
# State/Privince         Arizona
# Name: 681, dtype: object
#
#
# Site              42WS311775
# Region             Southwest
# State/Privince          Utah
# Name: 685, dtype: object
#
#
# Site              Gold Butte Site
# Region                  Southwest
# State/Privince             Nevada
# Name: 691, dtype: object
#
#
# Site               42WS3544
# Region            Southwest
# State/Privince         Utah
# Name: 694, dtype: object
#
#
# Site               42GA1437
# Region            Southwest
# State/Privince         Utah
# Name: 695, dtype: object
#
#
# Site               42WS3105
# Region            Southwest
# State/Privince         Utah
# Name: 696, dtype: object
#
#
# Site              Old Man Cave
# Region               Southwest
# State/Privince            Utah
# Name: 701, dtype: object
#
#
# Site              Pack Rat Cave
# Region                Southwest
# State/Privince          Arizona
# Name: 702, dtype: object
#
#
# Site              Phoenix Courthouse
# Region                     Southwest
# State/Privince               Arizona
# Name: 706, dtype: object
#
#
# Site               42KA3575
# Region            Southwest
# State/Privince         Utah
# Name: 708, dtype: object
#
#
# Site              Elsinore Burial
# Region                  Southwest
# State/Privince               Utah
# Name: 709, dtype: object
#
#
# Site              Old Wood Site
# Region                Southwest
# State/Privince             Utah
# Name: 711, dtype: object
#
#
# Site              White Basketmaker
# Region                    Southwest
# State/Privince                 Utah
# Name: 712, dtype: object
#
#
# Site              Finch Camp
# Region             Southwest
# State/Privince       Arizona
# Name: 713, dtype: object
#
#
# Site               42WN2234
# Region            Southwest
# State/Privince         Utah
# Name: 720, dtype: object
#
#
# Site              Cave du Pont
# Region               Southwest
# State/Privince            Utah
# Name: 721, dtype: object
#
#
# Site                LA144921
# Region             Southwest
# State/Privince    New Mexico
# Name: 724, dtype: object
#
#
# Site              Triangle Cave
# Region                Southwest
# State/Privince             Utah
# Name: 726, dtype: object
#
#
# Site              Bear Tracks
# Region              Southwest
# State/Privince           Utah
# Name: 728, dtype: object
#
#
# Site              Eagle Ridge
# Region              Southwest
# State/Privince        Arizona
# Name: 731, dtype: object
#
#
# Site              Panorama House
# Region                 Southwest
# State/Privince           Arizona
# Name: 732, dtype: object
#
#
# Site              Polly's Place
# Region                Southwest
# State/Privince          Arizona
# Name: 739, dtype: object
#
#
# Site              Antechamber Site
# Region                   Southwest
# State/Privince                Utah
# Name: 745, dtype: object
#
#
# Site              Clyde's Cavern
# Region                 Southwest
# State/Privince              Utah
# Name: 747, dtype: object
#
#
# Site                   42SA
# Region            Southwest
# State/Privince         Utah
# Name: 752, dtype: object
#
#
# Site              Dry Laid Heaven
# Region                  Southwest
# State/Privince               Utah
# Name: 756, dtype: object
#
#
# Site                U:9:178
# Region            Southwest
# State/Privince      Arizona
# Name: 761, dtype: object
#
#
# Site              Atlatl Rock Cave
# Region                   Southwest
# State/Privince             Arizona
# Name: 762, dtype: object
#
#
# Site                U:9:200
# Region            Southwest
# State/Privince      Arizona
# Name: 766, dtype: object
#
#
# Site               42KA3684
# Region            Southwest
# State/Privince         Utah
# Name: 768, dtype: object
#
#
# Site                42WN181
# Region            Southwest
# State/Privince         Utah
# Name: 769, dtype: object
#
#
# Site              Hoopes Shelter
# Region                 Southwest
# State/Privince              Utah
# Name: 770, dtype: object
#
#
# Site                     Valencia Vieja
# Region                        Southwest
# State/Privince    Arizona, Tucson Basin
# Name: 773, dtype: object
#
#
# Site              South Falls Creek Shelter
# Region                            Southwest
# State/Privince                     Colorado
# Name: 777, dtype: object
#
#
# Site              Bobobos Vista
# Region                Southwest
# State/Privince          Arizona
# Name: 781, dtype: object
#
#
# Site                Culvert
# Region            Southwest
# State/Privince         Utah
# Name: 784, dtype: object
#
#
# Site                 FB6772
# Region            Southwest
# State/Privince        Texas
# Name: 788, dtype: object
#
#
# Site               P:61:191
# Region            Southwest
# State/Privince      Arizona
# Name: 789, dtype: object
#
#
# Site              Paint Pot Village
# Region                    Southwest
# State/Privince                 Utah
# Name: 790, dtype: object
#
#
# Site               42GA4542
# Region            Southwest
# State/Privince      Arizona
# Name: 793, dtype: object
#
#
# Site              Steinaker Gap
# Region                Southwest
# State/Privince             Utah
# Name: 796, dtype: object
#
#
# Site              Yuma Wash
# Region            Southwest
# State/Privince      Arizona
# Name: 798, dtype: object
#
#
# Site              Pantry Alcove
# Region                Southwest
# State/Privince             Utah
# Name: 801, dtype: object
#
#
# Site               42GA6566
# Region            Southwest
# State/Privince         Utah
# Name: 806, dtype: object
#
#
# Site               42WN1897
# Region            Southwest
# State/Privince         Utah
# Name: 807, dtype: object
#
#
# Site               LA 71610
# Region            Southwest
# State/Privince     Colorado
# Name: 816, dtype: object
#
#
# Site                LA129573
# Region             Southwest
# State/Privince    New Mexico
# Name: 817, dtype: object
#
#
# Site                LA145984
# Region             Southwest
# State/Privince    New Mexico
# Name: 818, dtype: object
#
#
# Site              Little Cathedral
# Region                   Southwest
# State/Privince                Utah
# Name: 819, dtype: object
#
#
# Site              Raven's Roost
# Region                Southwest
# State/Privince             Utah
# Name: 820, dtype: object
#
#
# Site                 5LP570
# Region            Southwest
# State/Privince     Colorado
# Name: 824, dtype: object
#
#
# Site               42GA4543
# Region            Southwest
# State/Privince         Utah
# Name: 830, dtype: object
#
#
# Site              Lenox Park
# Region             Southwest
# State/Privince       Arizona
# Name: 836, dtype: object
#
#
# Site                42GA655
# Region            Southwest
# State/Privince         Utah
# Name: 839, dtype: object
#
#
# Site              Gypsum Cave
# Region              Southwest
# State/Privince         Nevada
# Name: 845, dtype: object
#
#
# Site                 LA80351
# Region             Southwest
# State/Privince    New Mexico
# Name: 846, dtype: object
#
#
# Site              Haught Ranch
# Region               Southwest
# State/Privince         Arizona
# Name: 850, dtype: object
#
#
# Site              Indian Canyon Pictographs
# Region                            Southwest
# State/Privince                         Utah
# Name: 851, dtype: object
#
#
# Site                  Paseo
# Region            Southwest
# State/Privince      Arizona
# Name: 853, dtype: object
#
#
# Site                O:1:105
# Region            Southwest
# State/Privince      Arizona
# Name: 859, dtype: object
#
#
# Site                 O:1:85
# Region            Southwest
# State/Privince      Arizona
# Name: 860, dtype: object
#
#
# Site               5MT10647
# Region            Southwest
# State/Privince     Colorado
# Name: 861, dtype: object
#
#
# Site              Jackrabbit Roast
# Region                   Southwest
# State/Privince                Utah
# Name: 864, dtype: object
#
#
# Site              Coal Bed Village
# Region                   Southwest
# State/Privince                Utah
# Name: 870, dtype: object
#
#
# Site               Fastimes
# Region            Southwest
# State/Privince      Arizona
# Name: 872, dtype: object
#
#
# Site               NA-20700
# Region            Southwest
# State/Privince      Arizona
# Name: 873, dtype: object
#
#
# Site              Pottery Mound
# Region                Southwest
# State/Privince       New Mexico
# Name: 874, dtype: object
#
#
# Site               42DC3053
# Region            Southwest
# State/Privince         Utah
# Name: 875, dtype: object
#
#
# Site              42SA25540
# Region            Southwest
# State/Privince         Utah
# Name: 876, dtype: object
#
#
# Site               42UN2889
# Region            Southwest
# State/Privince         Utah
# Name: 877, dtype: object
#
#
# Site                   Dean
# Region            Southwest
# State/Privince      Arizona
# Name: 878, dtype: object
#
#
# Site              Sheep Horn Alcove
# Region                    Southwest
# State/Privince                 Utah
# Name: 880, dtype: object
#
#
# Site              White Sheep
# Region              Southwest
# State/Privince           Utah
# Name: 881, dtype: object
#
#
# Site                42KA879
# Region            Southwest
# State/Privince         Utah
# Name: 883, dtype: object
#
#
# Site                LA139419
# Region             Southwest
# State/Privince    New Mexico
# Name: 884, dtype: object
#
#
# Site               42WN2400
# Region            Southwest
# State/Privince         Utah
# Name: 886, dtype: object
#
#
# Site              Basket Alcove
# Region                Southwest
# State/Privince             Utah
# Name: 888, dtype: object
#
#
# Site               42GA4538
# Region            Southwest
# State/Privince         Utah
# Name: 895, dtype: object
#
#
# Site              CC:2:289(ASM)
# Region                Southwest
# State/Privince          Arizona
# Name: 900, dtype: object
#
#
# Site              Dust Devil Site
# Region                  Southwest
# State/Privince               Utah
# Name: 902, dtype: object
#
#
# Site               5MT10736
# Region            Southwest
# State/Privince     Colorado
# Name: 907, dtype: object
#
#
# Site               La Villa
# Region            Southwest
# State/Privince      Arizona
# Name: 911, dtype: object
#
#
# Site                 LA79903
# Region             Southwest
# State/Privince    New Mexico
# Name: 913, dtype: object
#
#
# Site              Morss Cave 27
# Region                Southwest
# State/Privince             Utah
# Name: 914, dtype: object
#
#
# Site               42DC3367
# Region            Southwest
# State/Privince         Utah
# Name: 915, dtype: object
#
#
# Site                DD:1:75
# Region            Southwest
# State/Privince      Arizona
# Name: 919, dtype: object
#
#
# Site                U:9:222
# Region            Southwest
# State/Privince      Arizona
# Name: 922, dtype: object
#
#
# Site              Hawk's Nest
# Region              Southwest
# State/Privince        Arizona
# Name: 932, dtype: object
#
#
# Site               42KA5902
# Region            Southwest
# State/Privince         Utah
# Name: 933, dtype: object
#
#
# Site              Chuckwalla
# Region             Southwest
# State/Privince        Nevada
# Name: 935, dtype: object
#
#
# Site                   PACC
# Region            Southwest
# State/Privince      Arizona
# Name: 937, dtype: object
#
#
# Site              AR-0307-03-2623
# Region                  Southwest
# State/Privince            Arizona
# Name: 940, dtype: object
#
#
# Site              Broken Flute Cave
# Region                    Southwest
# State/Privince              Arizona
# Name: 941, dtype: object
#
#
# Site               42DC3145
# Region            Southwest
# State/Privince         Utah
# Name: 946, dtype: object
#
#
# Site              Arrowhead Hill
# Region                 Southwest
# State/Privince              Utah
# Name: 948, dtype: object
#
#
# Site              Gates Roost
# Region              Southwest
# State/Privince           Utah
# Name: 950, dtype: object
#
#
# Site              Elder Springs Shelter
# Region                        Southwest
# State/Privince                     Utah
# Name: 956, dtype: object
#
#
# Site              Honey Bee Village
# Region                    Southwest
# State/Privince              Arizona
# Name: 957, dtype: object
#
#
# Site                 5LP185
# Region            Southwest
# State/Privince     Colorado
# Name: 961, dtype: object
#
#
# Site              Cueva de los Indios
# Region                      Southwest
# State/Privince              Chihuahua
# Name: 964, dtype: object
#
#
# Site              Hidden Island
# Region                Southwest
# State/Privince             Utah
# Name: 965, dtype: object
#
#
# Site              Snaketown
# Region            Southwest
# State/Privince      Arizona
# Name: 967, dtype: object
#
#
# Site               42KA4535
# Region            Southwest
# State/Privince         Utah
# Name: 970, dtype: object
#
#
# Site              Trail Canyon Alcove
# Region                      Southwest
# State/Privince                   Utah
# Name: 976, dtype: object
#
#
# Site              Whitman Cave
# Region               Southwest
# State/Privince         Arizona
# Name: 978, dtype: object
#
#
# Site                LA112420
# Region             Southwest
# State/Privince    New Mexico
# Name: 981, dtype: object
#
#
# Site               42WS5164
# Region            Southwest
# State/Privince         Utah
# Name: 984, dtype: object
#
#
# Site               42EM3446
# Region            Southwest
# State/Privince         Utah
# Name: 990, dtype: object
#
#
# Site               5MT10711
# Region            Southwest
# State/Privince     Colorado
# Name: 992, dtype: object
#
#
# Site              Red Feather
# Region              Southwest
# State/Privince           Utah
# Name: 995, dtype: object
#
#
# Site              Sleeping Rainbow
# Region                   Southwest
# State/Privince                Utah
# Name: 996, dtype: object
#
#
# Site                U:9:223
# Region            Southwest
# State/Privince      Arizona
# Name: 997, dtype: object
#
#
# Site              Windrow Ruin
# Region               Southwest
# State/Privince        Colorado
# Name: 998, dtype: object
#
#
# Site              AR030703-1500
# Region                Southwest
# State/Privince          Arizona
# Name: 999, dtype: object
#
#
# Site               42GA4055
# Region            Southwest
# State/Privince         Utah
# Name: 1000, dtype: object
#
#
# Site              Coombs Cave
# Region              Southwest
# State/Privince           Utah
# Name: 1001, dtype: object
#
#
# Site              Desert Tortoise
# Region                  Southwest
# State/Privince            Arizona
# Name: 1002, dtype: object
#
#
# Site                LA145974
# Region             Southwest
# State/Privince    New Mexico
# Name: 1003, dtype: object
#
#
# Site               42KA4309
# Region            Southwest
# State/Privince         Utah
# Name: 1007, dtype: object
#
#
# Site               42KA6293
# Region            Southwest
# State/Privince         Utah
# Name: 1008, dtype: object
#
#
# Site               Shepherd
# Region            Southwest
# State/Privince     Colorado
# Name: 1013, dtype: object
#
#
# Site              Wolf Village
# Region               Southwest
# State/Privince            Utah
# Name: 1014, dtype: object
#
#
# Site              T:11:94(ASM)
# Region               Southwest
# State/Privince         Arizona
# Name: 1017, dtype: object
#
#
# Site              AA:16:410(ASM)
# Region                 Southwest
# State/Privince           Arizona
# Name: 1019, dtype: object
#
#
# Site               Oven Site
# Region             Southwest
# State/Privince    New Mexico
# Name: 1020, dtype: object
#
#
# Site               5MT10631
# Region            Southwest
# State/Privince     Colorado
# Name: 1026, dtype: object
#
#
# Site                 LA83871
# Region             Southwest
# State/Privince    New Mexico
# Name: 1032, dtype: object
#
#
# Site                P:60:31
# Region            Southwest
# State/Privince      Arizona
# Name: 1033, dtype: object
#
#
# Site              Rocky Point
# Region              Southwest
# State/Privince        Arizona
# Name: 1034, dtype: object
#
#
# Site              Deer Creek Pictographs
# Region                         Southwest
# State/Privince                      Utah
# Name: 1041, dtype: object
#
#
# Site              Sambrito Site
# Region                Southwest
# State/Privince       New Mexico
# Name: 1043, dtype: object
#
#
# Site              Victorio 88889
# Region                 Southwest
# State/Privince        New Mexico
# Name: 1044, dtype: object
#
#
# Site                42CB876
# Region            Southwest
# State/Privince         Utah
# Name: 1046, dtype: object
#
#
# Site                42WS195
# Region            Southwest
# State/Privince         Utah
# Name: 1047, dtype: object
#
#
# Site               42WS3887
# Region            Southwest
# State/Privince         Utah
# Name: 1048, dtype: object
#
#
# Site                 5LP240
# Region            Southwest
# State/Privince     Colorado
# Name: 1052, dtype: object
#
#
# Site              Beethoven
# Region            Southwest
# State/Privince      Arizona
# Name: 1055, dtype: object
#
#
# Site                LA103463
# Region             Southwest
# State/Privince    New Mexico
# Name: 1058, dtype: object
#
#
# Site               42KA1695
# Region            Southwest
# State/Privince         Utah
# Name: 1064, dtype: object
#
#
# Site                42TO504
# Region            Southwest
# State/Privince         Utah
# Name: 1065, dtype: object
#
#
# Site              Antler House Vilage
# Region                      Southwest
# State/Privince                Arizona
# Name: 1072, dtype: object
#
#
# Site                42KA877
# Region            Southwest
# State/Privince         Utah
# Name: 1082, dtype: object
#
#
# Site               42WS1931
# Region            Southwest
# State/Privince         Utah
# Name: 1083, dtype: object
#
#
# Site              LA5203/5204/32943
# Region                    Southwest
# State/Privince           New Mexico
# Name: 1089, dtype: object
#
#
# Site              Promontory Cave #2
# Region                     Southwest
# State/Privince                  Utah
# Name: 1093, dtype: object
#
#
# Site               42WN2278
# Region            Southwest
# State/Privince         Utah
# Name: 1095, dtype: object
#
#
# Site                 5LP239
# Region            Southwest
# State/Privince     Colorado
# Name: 1099, dtype: object
#
#
# Site              Confluence
# Region             Southwest
# State/Privince          Utah
# Name: 1102, dtype: object
#
#
# Site              Hot Spring
# Region             Southwest
# State/Privince          Utah
# Name: 1105, dtype: object
#
#
# Site              Mace's Cave
# Region              Southwest
# State/Privince           Utah
# Name: 1107, dtype: object
#
#
# Site              Vermillion Vista
# Region                   Southwest
# State/Privince                Utah
# Name: 1124, dtype: object
#
#
# Site              5MT106732
# Region            Southwest
# State/Privince     Colorado
# Name: 1125, dtype: object
#
#
# Site              Dutch Canal Ruin
# Region                   Southwest
# State/Privince             Arizona
# Name: 1129, dtype: object
#
#
# Site                LA116531
# Region             Southwest
# State/Privince    New Mexico
# Name: 1132, dtype: object
#
#
# Site                GR-893
# Region            Southwest
# State/Privince      Arizona
# Name: 1140, dtype: object
#
#
# Site               42KA5904
# Region            Southwest
# State/Privince         Utah
# Name: 1141, dtype: object
#
#
# Site                 5LP177
# Region            Southwest
# State/Privince     Colorado
# Name: 1143, dtype: object
#
#
# Site              Barnson Site
# Region               Southwest
# State/Privince            Utah
# Name: 1144, dtype: object
#
#
# Site              Birch Creek Shelter
# Region                      Southwest
# State/Privince                   Utah
# Name: 1146, dtype: object
#
#
# Site                LA103464
# Region             Southwest
# State/Privince    New Mexico
# Name: 1149, dtype: object
#
#
# Site              Park Wash
# Region            Southwest
# State/Privince         Utah
# Name: 1151, dtype: object
#
#
# Site              Sopris Site
# Region              Southwest
# State/Privince       Colorado
# Name: 1153, dtype: object
#
#
# Site              U:9:310(ASM)
# Region               Southwest
# State/Privince         Arizona
# Name: 1155, dtype: object
#
#
# Site              Trowbridge
# Region                Plains
# State/Privince        Kansas
# Name: 1158, dtype: object
#
#
# Site                  Aker
# Region              Plains
# State/Privince    Missouri
# Name: 1159, dtype: object
#
#
# Site               23PL285
# Region              Plains
# State/Privince    Missouri
# Name: 1160, dtype: object
#
#
# Site                25RH70
# Region              Plains
# State/Privince    Nebraska
# Name: 1161, dtype: object
#
#
# Site              James Younkin
# Region                   Plains
# State/Privince           Kansas
# Name: 1163, dtype: object
#
#
# Site               Berry
# Region            Plains
# State/Privince    Kansas
# Name: 1165, dtype: object
#
#
# Site              14LN344
# Region             Plains
# State/Privince     Kansas
# Name: 1170, dtype: object
#
#
# Site               Schultz
# Region              Plains
# State/Privince    Nebraska
# Name: 1172, dtype: object
#
#
# Site                 Young
# Region              Plains
# State/Privince    Nebraska
# Name: 1174, dtype: object
#
#
# Site               Miniota
# Region              Plains
# State/Privince    Manitoba
# Name: 1175, dtype: object
#
#
# Site              14JN332
# Region             Plains
# State/Privince     Kansas
# Name: 1176, dtype: object
#
#
# Site                     32BL8
# Region                  Plains
# State/Privince    North Dakota
# Name: 1178, dtype: object
#
#
# Site                    39ST56
# Region                  Plains
# State/Privince    South Dakota
# Name: 1179, dtype: object
#
#
# Site              13LE648
# Region             Plains
# State/Privince       Iowa
# Name: 1180, dtype: object
#
#
# Site                25DO12
# Region              Plains
# State/Privince    Nebraska
# Name: 1183, dtype: object
#
#
# Site              14EL313
# Region             Plains
# State/Privince     Kansas
# Name: 1185, dtype: object
#
#
# Site              13ML138
# Region             Plains
# State/Privince       Iowa
# Name: 1186, dtype: object
#
#
# Site                36HP70
# Region              Plains
# State/Privince    Oklahoma
# Name: 1187, dtype: object
#
#
# Site              23LE178/357
# Region                 Plains
# State/Privince       Missouri
# Name: 1188, dtype: object
#
#
# Site              13WD88
# Region            Plains
# State/Privince      Iowa
# Name: 1189, dtype: object
#
#
# Site              14NT11
# Region            Plains
# State/Privince    Kansas
# Name: 1190, dtype: object
#
#
# Site              14LV401
# Region             Plains
# State/Privince     Kansas
# Name: 1192, dtype: object
#
#
# Site              14WB504
# Region             Plains
# State/Privince       Iowa
# Name: 1193, dtype: object
#
#
# Site                21HE211
# Region               Plains
# State/Privince    Minnesota
# Name: 1195, dtype: object
#
#
# Site               34CU306
# Region              Plains
# State/Privince    Oklahoma
# Name: 1197, dtype: object
#
#
# Site              14SA414
# Region             Plains
# State/Privince     Kansas
# Name: 1204, dtype: object
#
#
# Site              14BU55
# Region            Plains
# State/Privince    Kansas
# Name: 1205, dtype: object
#
#
# Site              14LV357
# Region             Plains
# State/Privince     Kansas
# Name: 1208, dtype: object
#
#
# Site              14OS314
# Region             Plains
# State/Privince     Kansas
# Name: 1209, dtype: object
#
#
# Site              14DO19
# Region            Plains
# State/Privince    Kansas
# Name: 1210, dtype: object
#
#
# Site              14GE600
# Region             Plains
# State/Privince     Kansas
# Name: 1211, dtype: object
#
#
# Site               Cross
# Region            Plains
# State/Privince      Iowa
# Name: 1213, dtype: object
#
#
# Site                  21GD3
# Region               Plains
# State/Privince    Minnesota
# Name: 1214, dtype: object
#
#
# Site               Wallace
# Region              Plains
# State/Privince    Colorado
# Name: 1215, dtype: object
#
#
# Site              Whiteford
# Region               Plains
# State/Privince       Kansas
# Name: 1216, dtype: object
#
#
# Site                  21BE2
# Region               Plains
# State/Privince    Minnesota
# Name: 1218, dtype: object
#
#
# Site              Horseshoe
# Region               Plains
# State/Privince         Iowa
# Name: 1220, dtype: object
#
#
# Site                21HE210
# Region               Plains
# State/Privince    Minnesota
# Name: 1221, dtype: object
#
#
# Site               23CL109
# Region              Plains
# State/Privince    Missouri
# Name: 1223, dtype: object
#
#
# Site              13ML12
# Region            Plains
# State/Privince      Iowa
# Name: 1225, dtype: object
#
#
# Site              14MP407
# Region             Plains
# State/Privince     Kansas
# Name: 1226, dtype: object
#
#
# Site              13ML130
# Region             Plains
# State/Privince       Iowa
# Name: 1233, dtype: object
#
#
# Site                 White
# Region              Plains
# State/Privince    Missouri
# Name: 1235, dtype: object
#
#
# Site                  21GD4
# Region               Plains
# State/Privince    Minnesota
# Name: 1239, dtype: object
#
#
# Site                    32EM10
# Region                  Plains
# State/Privince    North Dakota
# Name: 1245, dtype: object
#
#
# Site                25SY31
# Region              Plains
# State/Privince    Nebraska
# Name: 1246, dtype: object
#
#
# Site                   39LM208
# Region                  Plains
# State/Privince    South Dakota
# Name: 1252, dtype: object
#
#
# Site               14OT5
# Region            Plains
# State/Privince    Kansas
# Name: 1253, dtype: object
#
#
# Site                 25BD1
# Region              Plains
# State/Privince    Nebraska
# Name: 1255, dtype: object
#
#
# Site                21GD159
# Region               Plains
# State/Privince    Minnesota
# Name: 1256, dtype: object
#
#
# Site              14DP25
# Region            Plains
# State/Privince    Kansas
# Name: 1258, dtype: object
#
#
# Site                     39PO7
# Region                  Plains
# State/Privince    South Dakota
# Name: 1260, dtype: object
#
#
# Site                     39CA1
# Region                  Plains
# State/Privince    South Dakota
# Name: 1262, dtype: object
#
#
# Site                25BW15
# Region              Plains
# State/Privince    Nebraska
# Name: 1265, dtype: object
#
#
# Site                   39LM146
# Region                  Plains
# State/Privince    South Dakota
# Name: 1266, dtype: object
#
#
# Site              14RY401
# Region             Plains
# State/Privince     Kansas
# Name: 1267, dtype: object
#
#
# Site               25BD139
# Region              Plains
# State/Privince    Nebraska
# Name: 1268, dtype: object
#
#
# Site                25BD16
# Region              Plains
# State/Privince    Nebraska
# Name: 1269, dtype: object
#
#
# Site               25WH301
# Region              Plains
# State/Privince    Nebraska
# Name: 1271, dtype: object
#
#
# Site                   32SN110
# Region                  Plains
# State/Privince    North Dakota
# Name: 1272, dtype: object
#
#
# Site                   32SN247
# Region                  Plains
# State/Privince    North Dakota
# Name: 1273, dtype: object
#
#
# Site                23PL80
# Region              Plains
# State/Privince    Missouri
# Name: 1274, dtype: object
#
#
# Site               34BV100
# Region              Plains
# State/Privince    Oklahoma
# Name: 1275, dtype: object
#
#
# Site                     39CO6
# Region                  Plains
# State/Privince    South Dakota
# Name: 1276, dtype: object
#
#
# Site                   32SN113
# Region                  Plains
# State/Privince    North Dakota
# Name: 1278, dtype: object
#
#
# Site              14CY17
# Region            Plains
# State/Privince    Kansas
# Name: 1283, dtype: object
#
#
# Site              14LV1071
# Region              Plains
# State/Privince      Kansas
# Name: 1286, dtype: object
#
#
# Site               34GV156
# Region              Plains
# State/Privince    Oklahoma
# Name: 1287, dtype: object
#
#
# Site                   39HU242
# Region                  Plains
# State/Privince    South Dakota
# Name: 1288, dtype: object
#
#
# Site              14JW301
# Region             Plains
# State/Privince     Kansas
# Name: 1292, dtype: object
#
#
# Site                34GD81
# Region              Plains
# State/Privince    Oklahoma
# Name: 1295, dtype: object
#
#
# Site              13ML126
# Region             Plains
# State/Privince       Iowa
# Name: 1299, dtype: object
#
#
# Site              14CY102
# Region             Plains
# State/Privince     Kansas
# Name: 1300, dtype: object
#
#
# Site              13ML361
# Region             Plains
# State/Privince       Iowa
# Name: 1301, dtype: object
#
#
# Site                34GV22
# Region              Plains
# State/Privince    Oklahoma
# Name: 1302, dtype: object
#
#
# Site               14CY4
# Region            Plains
# State/Privince    Kansas
# Name: 1304, dtype: object
#
#
# Site                 25BD2
# Region              Plains
# State/Privince    Nebraska
# Name: 1306, dtype: object
#
#
# Site               25HW301
# Region              Plains
# State/Privince    Nebraska
# Name: 1307, dtype: object
#
#
# Site              14SD305
# Region             Plains
# State/Privince     Kansas
# Name: 1309, dtype: object
#
#
# Site               14CY1
# Region            Plains
# State/Privince    Kansas
# Name: 1311, dtype: object
#
#
# Site                 21FA72
# Region               Plains
# State/Privince    Minnesota
# Name: 1312, dtype: object
#
#
# Site                   39DW231
# Region                  Plains
# State/Privince    South Dakota
# Name: 1314, dtype: object
#
#
# Site              13ML176
# Region             Plains
# State/Privince       Iowa
# Name: 1321, dtype: object
#
#
# Site              14RY10
# Region            Plains
# State/Privince    Kansas
# Name: 1323, dtype: object
#
#
# Site               34GV264
# Region              Plains
# State/Privince    Oklahoma
# Name: 1328, dtype: object
#
#
# Site              14GE127
# Region             Plains
# State/Privince     Kansas
# Name: 1329, dtype: object
#
#
# Site                     32EM1
# Region                  Plains
# State/Privince    North Dakota
# Name: 1336, dtype: object
#
#
# Site                 21FA97
# Region               Plains
# State/Privince    Minnesota
# Name: 1337, dtype: object
#
#
# Site                   32SN246
# Region                  Plains
# State/Privince    North Dakota
# Name: 1338, dtype: object
#
#
# Site              13ML429
# Region             Plains
# State/Privince       Iowa
# Name: 1341, dtype: object
#
#
# Site               34CU220
# Region              Plains
# State/Privince    Oklahoma
# Name: 1342, dtype: object
#
#
# Site                34TX32
# Region              Plains
# State/Privince    Oklahoma
# Name: 1344, dtype: object
#
#
# Site              14RH301
# Region             Plains
# State/Privince     Kansas
# Name: 1346, dtype: object
#
#
# Site                25FT56
# Region              Plains
# State/Privince    Nebraska
# Name: 1347, dtype: object
#
#
# Site                Vinette
# Region            Northeast
# State/Privince     New York
# Name: 1349, dtype: object
#
#
# Site              Place-Royale
# Region               Northeast
# State/Privince          Quebec
# Name: 1350, dtype: object
#
#
# Site                 Winter
# Region            Northeast
# State/Privince     Michigan
# Name: 1352, dtype: object
#
#
# Site              Hector-Trudel
# Region                Northeast
# State/Privince           Quebec
# Name: 1354, dtype: object
#
#
# Site               Fortin 2
# Region            Northeast
# State/Privince     New York
# Name: 1357, dtype: object
#
#
# Site               20SA1276
# Region            Northeast
# State/Privince     Michigan
# Name: 1359, dtype: object
#
#
# Site               Cloudman
# Region            Northeast
# State/Privince     Michigan
# Name: 1362, dtype: object
#
#
# Site              D. Hitchens
# Region              Northeast
# State/Privince       Illinois
# Name: 1364, dtype: object
#
#
# Site              Westheimer
# Region             Northeast
# State/Privince      New York
# Name: 1365, dtype: object
#
#
# Site                  Felix
# Region            Northeast
# State/Privince     New York
# Name: 1366, dtype: object
#
#
# Site              Grand Banks
# Region              Northeast
# State/Privince        Ontario
# Name: 1367, dtype: object
#
#
# Site                 Ellege
# Region            Northeast
# State/Privince     Illinois
# Name: 1371, dtype: object
#
#
# Site              Kipp Island
# Region              Northeast
# State/Privince       New York
# Name: 1372, dtype: object
#
#
# Site                 Turpin
# Region            Northeast
# State/Privince         Ohio
# Name: 1373, dtype: object
#
#
# Site                Wickham
# Region            Northeast
# State/Privince     New York
# Name: 1376, dtype: object
#
#
# Site                Simmons
# Region            Northeast
# State/Privince     New York
# Name: 1377, dtype: object
#
#
# Site              Edger Hoener
# Region               Northeast
# State/Privince        Illinois
# Name: 1379, dtype: object
#
#
# Site                  Allen
# Region            Northeast
# State/Privince         Ohio
# Name: 1381, dtype: object
#
#
# Site                  Meyer
# Region            Northeast
# State/Privince      Ontario
# Name: 1382, dtype: object
#
#
# Site              Hunters Home
# Region               Northeast
# State/Privince        New York
# Name: 1386, dtype: object
#
#
# Site              Deposit Airport 1
# Region                    Northeast
# State/Privince             New York
# Name: 1389, dtype: object
#
#
# Site                Forster
# Region            Northeast
# State/Privince      Ontario
# Name: 1391, dtype: object
#
#
# Site                  Solms
# Region            Northeast
# State/Privince     Michigan
# Name: 1393, dtype: object
#
#
# Site                211-1-1
# Region            Northeast
# State/Privince     New York
# Name: 1394, dtype: object
#
#
# Site                Holding
# Region            Northeast
# State/Privince     Illinois
# Name: 1395, dtype: object
#
#
# Site               Tickless
# Region            Northeast
# State/Privince     Illinois
# Name: 1397, dtype: object
#
#
# Site              Broome Tech
# Region              Northeast
# State/Privince       New York
# Name: 1399, dtype: object
#
#
# Site                 Street
# Region            Northeast
# State/Privince     New York
# Name: 1400, dtype: object
#
#
# Site              Shoemaker's Ferry
# Region                    Northeast
# State/Privince           New Jersey
# Name: 1401, dtype: object
#
#
# Site              Lone Pine
# Region            Northeast
# State/Privince      Ontario
# Name: 1402, dtype: object
#
#
# Site                Nodwell
# Region            Northeast
# State/Privince      Ontario
# Name: 1403, dtype: object
#
#
# Site              Holmedale
# Region            Northeast
# State/Privince      Ontario
# Name: 1404, dtype: object
#
#
# Site                Cahokia
# Region            Northeast
# State/Privince     Illinois
# Name: 1405, dtype: object
#
#
# Site              East St. Louis Mound Group
# Region                             Northeast
# State/Privince                      Illinois
# Name: 1406, dtype: object
#
#
# Site              Kuhlman Habitation
# Region                     Northeast
# State/Privince              Illinois
# Name: 1407, dtype: object
#
#
# Site              Memorial Park
# Region                Northeast
# State/Privince     Pennsylvania
# Name: 1409, dtype: object
#
#
# Site              Sponemann
# Region            Northeast
# State/Privince     Illinois
# Name: 1410, dtype: object
#
#
# Site               Spoontoe
# Region            Northeast
# State/Privince     Illinois
# Name: 1411, dtype: object
#
#
# Site                Emerald
# Region            Northeast
# State/Privince     Illinois
# Name: 1412, dtype: object
#
#
# Site              Washausen
# Region            Northeast
# State/Privince     Illinois
# Name: 1414, dtype: object
#
#
# Site                    Ingalls
# Region                Northeast
# State/Privince    New Hampshire
# Name: 1415, dtype: object
#
#
# Site              Bulls Point
# Region              Northeast
# State/Privince        Ontario
# Name: 1417, dtype: object
#
#
# Site                   Dick
# Region            Northeast
# State/Privince      Ontario
# Name: 1423, dtype: object
#
#
# Site                 Audrey
# Region            Northeast
# State/Privince     Illinois
# Name: 1427, dtype: object
#
#
# Site                  Kasheta
# Region              Northeast
# State/Privince    Connecticut
# Name: 1430, dtype: object
#
#
# Site              State Line
# Region             Northeast
# State/Privince          Ohio
# Name: 1431, dtype: object
#
#
# Site              Kingston Lake
# Region                Northeast
# State/Privince         Illinois
# Name: 1432, dtype: object
#
#
# Site                Webster
# Region            Northeast
# State/Privince     Illinois
# Name: 1433, dtype: object
#
#
# Site              Herrick Hollow II
# Region                    Northeast
# State/Privince             New York
# Name: 1434, dtype: object
#
#
# Site                   Lamb
# Region            Northeast
# State/Privince     Illinois
# Name: 1435, dtype: object
#
#
# Site              Chenango Point
# Region                 Northeast
# State/Privince          New York
# Name: 1438, dtype: object
#
#
# Site                Parsons
# Region            Northeast
# State/Privince      Ontario
# Name: 1439, dtype: object
#
#
# Site              Pierre Marquette
# Region                   Northeast
# State/Privince            Illinois
# Name: 1441, dtype: object
#
#
# Site              Roeliff Jansen Kill
# Region                      Northeast
# State/Privince               New York
# Name: 1443, dtype: object
#
#
# Site              Schomaker
# Region            Northeast
# State/Privince         Ohio
# Name: 1444, dtype: object
#
#
# Site              Kimmel Mine No. 1
# Region                    Northeast
# State/Privince         Pennsylvania
# Name: 1445, dtype: object
#
#
# Site                 Cooper
# Region            Northeast
# State/Privince     Illinois
# Name: 1447, dtype: object
#
#
# Site              Thomas/Luckey
# Region                Northeast
# State/Privince         New York
# Name: 1449, dtype: object
#
#
# Site              Headquarters
# Region               Northeast
# State/Privince         Vermont
# Name: 1450, dtype: object
#
#
# Site              Ventura Tract
# Region                Northeast
# State/Privince       New Jersey
# Name: 1451, dtype: object
#
#
# Site               Roundtop
# Region            Northeast
# State/Privince     New York
# Name: 1452, dtype: object
#
#
# Site                   Uren
# Region            Northeast
# State/Privince      Ontario
# Name: 1453, dtype: object
#
#
# Site                Roskamp
# Region            Northeast
# State/Privince     Illinois
# Name: 1457, dtype: object
#
#
# Site                   Losey 3
# Region               Northeast
# State/Privince    Pennsylvania
# Name: 1458, dtype: object
#
#
# Site              Horseshoe Johnson
# Region                    Northeast
# State/Privince                 Ohio
# Name: 1461, dtype: object
#
#
# Site                Kincaid
# Region            Northeast
# State/Privince     Illinois
# Name: 1463, dtype: object
#
#
# Site                    Consol
# Region               Northeast
# State/Privince    Pennsylvania
# Name: 1466, dtype: object
#
#
# Site              Campbell Farm
# Region                Northeast
# State/Privince     Pennsylvania
# Name: 1467, dtype: object
#
#
# Site              Maxon-Derby
# Region              Northeast
# State/Privince       New York
# Name: 1470, dtype: object
#
#
# Site              Cahokia Mounds
# Region                 Northeast
# State/Privince          Illinois
# Name: 1471, dtype: object
#
#
# Site              Hill Creek
# Region             Northeast
# State/Privince      Illinois
# Name: 1474, dtype: object
#
#
# Site               Orendorf
# Region            Northeast
# State/Privince     Illinois
# Name: 1475, dtype: object
#
#
# Site              Wellington
# Region             Northeast
# State/Privince       Ontario
# Name: 1477, dtype: object
#
#
# Site                  Hibou
# Region            Northeast
# State/Privince      Ontario
# Name: 1483, dtype: object
#
#
# Site               Anderson
# Region            Northeast
# State/Privince      Ontario
# Name: 1485, dtype: object
#
#
# Site              Crawford Lake
# Region                Northeast
# State/Privince          Ontario
# Name: 1486, dtype: object
#
#
# Site                 Larson
# Region            Northeast
# State/Privince     Illinois
# Name: 1487, dtype: object
#
#
# Site              294A-25-2
# Region            Northeast
# State/Privince     New York
# Name: 1488, dtype: object
#
#
# Site                 Mary Rinn
# Region               Northeast
# State/Privince    Pennsylvania
# Name: 1489, dtype: object
#
#
# Site              Bonisteel
# Region            Northeast
# State/Privince      Ontario
# Name: 1493, dtype: object
#
#
# Site                 Hurley
# Region            Northeast
# State/Privince     New York
# Name: 1498, dtype: object
#
#
# Site                 Morton
# Region            Northeast
# State/Privince     Illinois
# Name: 1499, dtype: object
#
#
# Site                    Gnagey
# Region               Northeast
# State/Privince    Pennsylvania
# Name: 1500, dtype: object
#
#
# Site                  Snell
# Region            Northeast
# State/Privince     New York
# Name: 1501, dtype: object
#
#
# Site                CT294A-25
# Region              Northeast
# State/Privince    Connecticut
# Name: 1502, dtype: object
#
#
# Site                Pethick
# Region            Northeast
# State/Privince     New York
# Name: 1505, dtype: object
#
#
# Site               Sunwatch
# Region            Northeast
# State/Privince         Ohio
# Name: 1507, dtype: object
#
#
# Site                   Holy
# Region            Northeast
# State/Privince      Ontario
# Name: 1508, dtype: object
#
#
# Site                  Bates
# Region            Northeast
# State/Privince     New York
# Name: 1510, dtype: object
#
#
# Site              Otsiningo Market
# Region                   Northeast
# State/Privince            New York
# Name: 1511, dtype: object
#
#
# Site                Dykstra
# Region            Northeast
# State/Privince      Ontario
# Name: 1513, dtype: object
#
#
# Site              Washington Irving
# Region                    Northeast
# State/Privince             Illinois
# Name: 1517, dtype: object
#
#
# Site              Park Creek II
# Region                Northeast
# State/Privince         New York
# Name: 1520, dtype: object
#
#
# Site              Pere Marquette
# Region                 Northeast
# State/Privince          Illinois
# Name: 1521, dtype: object
#
#
# Site              National Guard Road
# Region                      Northeast
# State/Privince                Vermont
# Name: 1524, dtype: object
#
#
# Site              Briggs Run
# Region             Northeast
# State/Privince      New York
# Name: 1527, dtype: object
#
#
# Site                  Kelso
# Region            Northeast
# State/Privince     New York
# Name: 1531, dtype: object
#
#
# Site              Onoville Bridge
# Region                  Northeast
# State/Privince           New York
# Name: 1532, dtype: object
#
#
# Site              Burnham-Shepard
# Region                  Northeast
# State/Privince        Connecticut
# Name: 1533, dtype: object
#
#
# Site              Myrick's Pond
# Region                Northeast
# State/Privince    Massachusetts
# Name: 1534, dtype: object
#
#
# Site              Princess Point
# Region                 Northeast
# State/Privince           Ontario
# Name: 1535, dtype: object
#
#
# Site              Worthy-Merrigan
# Region                  Northeast
# State/Privince           Illinois
# Name: 1538, dtype: object
#
#
# Site              Hahn's Field
# Region               Northeast
# State/Privince            Ohio
# Name: 1540, dtype: object
#
#
# Site              Bowman's Brook
# Region                 Northeast
# State/Privince          New York
# Name: 1541, dtype: object
#
#
# Site                  Johnston
# Region               Northeast
# State/Privince    Pennsylvania
# Name: 1542, dtype: object
#
#
# Site                     Saddle
# Region                Northeast
# State/Privince    West Virginia
# Name: 1544, dtype: object
#
#
# Site                   Morgan
# Region              Northeast
# State/Privince    Connecticut
# Name: 1545, dtype: object
#
#
# Site                 Engelbrook
# Region                Northeast
# State/Privince    Massachusetts
# Name: 1547, dtype: object
#
#
# Site                      Heron
# Region                Northeast
# State/Privince    Massachusetts
# Name: 1548, dtype: object
#
#
# Site              Chenango Point South
# Region                       Northeast
# State/Privince                New York
# Name: 1550, dtype: object
#
#
# Site                 Barrie
# Region            Northeast
# State/Privince      Ontario
# Name: 1553, dtype: object
#
#
# Site              Bathurst St
# Region              Northeast
# State/Privince        Ontario
# Name: 1555, dtype: object
#
#
# Site                VTRU627
# Region            Northeast
# State/Privince      Vermont
# Name: 1560, dtype: object
#
#
# Site                Farrell
# Region            Northeast
# State/Privince     New York
# Name: 1561, dtype: object
#
#
# Site                 Garoga
# Region            Northeast
# State/Privince     New York
# Name: 1562, dtype: object
#
#
# Site              Little Ospie North
# Region                     Northeast
# State/Privince                 Maine
# Name: 1568, dtype: object
#
#
# Site                  Wales
# Region            Northeast
# State/Privince      Vermont
# Name: 1569, dtype: object
